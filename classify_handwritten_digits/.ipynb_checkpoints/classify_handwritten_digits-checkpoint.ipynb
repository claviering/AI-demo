# %%
import tensorflow as tf
from tensorflow import keras
mnist = keras.datasets.mnist

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 83s 7us/step

# %%
print(tf.__version__)
# Out:
# 2.0.0

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
network = tf.keras.Sequential()

# %%
network.add(tf.layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
network.add(tf.layers.Dense(10, activation='softmax'))
network.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# --------------------------------------------------
# AttributeError   Traceback (most recent call last)
# <ipython-input-7-06e5c260c806> in <module>
# ----> 1 network.add(tf.layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
#       2 network.add(tf.layers.Dense(10, activation='softmax'))
#       3 network.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
#
# AttributeError: module 'tensorflow' has no attribute 'layers'

# %%
network.add(tf.keras.layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
network.add(tf.keras.layers.Dense(10, activation='softmax'))
network.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255
train_labels = tf.keras.utils.to_categorical(train_labels)
test_labels = tf.keras.utils.to_categorical(test_labels)

# %%
network.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.2528 - accuracy: 0.9270
# Epoch 2/5
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.1024 - accuracy: 0.9691
# Epoch 3/5
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.0691 - accuracy: 0.9799
# Epoch 4/5
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.0497 - accuracy: 0.9846
# Epoch 5/5
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.0377 - accuracy: 0.9888

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# test_acc: 0.9796

# %%
import matplotlib.pyplot as plt

# %%
history = network.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 5s 75us/sample - loss: 0.0285 - accuracy: 0.9912
# Epoch 2/5
# 60000/60000 [==============================] - 5s 84us/sample - loss: 0.0220 - accuracy: 0.9936
# Epoch 3/5
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.0171 - accuracy: 0.9950
# Epoch 4/5
# 60000/60000 [==============================] - 4s 67us/sample - loss: 0.0132 - accuracy: 0.9963
# Epoch 5/5
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.0103 - accuracy: 0.9971

# %%
plt.xlabel('Epoch Number')
plt.ylabel("Loss Magnitude")
plt.plot(history.history['loss'])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
print(history.history)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-820f85b80291> in <module>
# ----> 1 print(history.history)
#
# NameError: name 'history' is not defined
